# %% [markdown]
# <a href="https://colab.research.google.com/github/kyl3rmanga/house-pricing-prediction/blob/main/kyl3r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing=pd.read_csv('housing.csv')
#importing the data to a variable called housing

# %%
housing
#calling the data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing.dropna(inplace=True)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=housing.drop(['median_house_value'],axis=1)
y=housing['median_house_value']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4425     -118.24     34.07                27.0        223.0            80.0
# 9665     -120.12     41.40                33.0       2820.0           515.0
# 18872    -122.20     38.09                18.0       6860.0          1079.0
# 18526    -122.04     36.97                52.0       1901.0           335.0
# 6284     -117.93     34.03                30.0       2246.0           446.0
# ...          ...       ...                 ...          ...             ...
# 6763     -118.13     34.10                26.0       3050.0           825.0
# 17665    -121.87     37.32                39.0       1839.0           471.0
# 7950     -118.15     33.86                36.0       1578.0           312.0
# 3416     -118.41     34.29                32.0       1591.0           320.0
# 11173    -117.97     33.83                22.0       3310.0           688.0
#
#        population  households  median_income ocean_proximity
# 4425        249.0        82.0         1.6136       <1H OCEAN
# 9665        976.0       403.0         2.6062          INLAND
# 18872      3205.0      1058.0         5.2957        NEAR BAY
# 18526       955.0       301.0         3.8259      NEAR OCEAN
# 6284       1837.0       431.0         4.7917       <1H OCEAN
# ...           ...         ...            ...             ...
# 6763       2153.0       772.0         3.1103       <1H OCEAN
# 17665      1528.0       456.0         2.6818       <1H OCEAN
# 7950        827.0       311.0         4.8942       <1H OCEAN
# 3416       1818.0       306.0         4.2969       <1H OCEAN
# 11173      1807.0       674.0         4.0185       <1H OCEAN
#
# [16346 rows x 9 columns]

# %%
y_train
# Out:
# 4425     137500.0
# 9665      52600.0
# 18872    171900.0
# 18526    253100.0
# 6284     164500.0
#            ...
# 6763     214100.0
# 17665    184900.0
# 7950     194100.0
# 3416     145800.0
# 11173    200900.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
train_housing=x_train.join(y_train)

# %%
train_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4425     -118.24     34.07                27.0        223.0            80.0
# 9665     -120.12     41.40                33.0       2820.0           515.0
# 18872    -122.20     38.09                18.0       6860.0          1079.0
# 18526    -122.04     36.97                52.0       1901.0           335.0
# 6284     -117.93     34.03                30.0       2246.0           446.0
# ...          ...       ...                 ...          ...             ...
# 6763     -118.13     34.10                26.0       3050.0           825.0
# 17665    -121.87     37.32                39.0       1839.0           471.0
# 7950     -118.15     33.86                36.0       1578.0           312.0
# 3416     -118.41     34.29                32.0       1591.0           320.0
# 11173    -117.97     33.83                22.0       3310.0           688.0
#
#        population  households  median_income ocean_proximity  \
# 4425        249.0        82.0         1.6136       <1H OCEAN
# 9665        976.0       403.0         2.6062          INLAND
# 18872      3205.0      1058.0         5.2957        NEAR BAY
# 18526       955.0       301.0         3.8259      NEAR OCEAN
# 6284       1837.0       431.0         4.7917       <1H OCEAN
# ...           ...         ...            ...             ...
# 6763       2153.0       772.0         3.1103       <1H OCEAN
# 17665      1528.0       456.0         2.6818       <1H OCEAN
# 7950        827.0       311.0         4.8942       <1H OCEAN
# 3416       1818.0       306.0         4.2969       <1H OCEAN
# 11173      1807.0       674.0         4.0185       <1H OCEAN
#
#        median_house_value
# 4425             137500.0
# 9665              52600.0
# 18872            171900.0
# 18526            253100.0
# 6284             164500.0
# ...                   ...
# 6763             214100.0
# 17665            184900.0
# 7950             194100.0
# 3416             145800.0
# 11173            200900.0
#
# [16346 rows x 10 columns]

# %%
train_housing.hist(figsize=(17,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_housing.corr()
# Out:
# <ipython-input-24-03cce89235eb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_housing.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924222           -0.110274     0.048106
# latitude            -0.924222  1.000000            0.011669    -0.039368
# housing_median_age  -0.110274  0.011669            1.000000    -0.360529
# total_rooms          0.048106 -0.039368           -0.360529     1.000000
# total_bedrooms       0.072417 -0.070048           -0.319930     0.930916
# population           0.105016 -0.113113           -0.291977     0.854200
# households           0.059940 -0.075053           -0.301587     0.917956
# median_income       -0.016420 -0.079183           -0.117143     0.194045
# median_house_value  -0.045011 -0.145234            0.111334     0.127734
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072417    0.105016    0.059940      -0.016420
# latitude                 -0.070048   -0.113113   -0.075053      -0.079183
# housing_median_age       -0.319930   -0.291977   -0.301587      -0.117143
# total_rooms               0.930916    0.854200    0.917956       0.194045
# total_bedrooms            1.000000    0.874128    0.979377      -0.011860
# population                0.874128    1.000000    0.903829       0.001223
# households                0.979377    0.903829    1.000000       0.008297
# median_income            -0.011860    0.001223    0.008297       1.000000
# median_house_value        0.045877   -0.031505    0.059709       0.685727
#
#                     median_house_value
# longitude                    -0.045011
# latitude                     -0.145234
# housing_median_age            0.111334
# total_rooms                   0.127734
# total_bedrooms                0.045877
# population                   -0.031505
# households                    0.059709
# median_income                 0.685727
# median_house_value            1.000000

# %%
plt.figure(figsize=(17,9))
sns.heatmap(train_housing.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_housing['total_rooms']=np.log(train_housing['total_rooms']+1)
train_housing['total_bedrooms']=np.log(train_housing['total_bedrooms']+1)
train_housing['population']=np.log(train_housing['population']+1)
train_housing['households']=np.log(train_housing['households']+1)

# %%
train_housing.hist(figsize=(17,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_housing=train_housing.join(pd.get_dummies(train_housing.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_housing['bedroom_ratio']=train_housing['total_bedrooms']/train_housing['total_rooms']
train_housing['household_rooms']=train_housing['total_rooms']/train_housing['households']

# %%
plt.figure(figsize=(17,9))
sns.heatmap(train_housing.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

x_train,y_train=train_housing.drop(['median_house_value'],axis=1),train_housing['median_house_value']

reg=LinearRegression()

reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2955bb28a6a1> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2
# ----> 3 x_train,y_train=train_housing.drop(['median_house_value'],axis=1),train_housing['median_house_value']
#       4
#       5 reg=LinearRegression()
#
# NameError: name 'train_housing' is not defined

# %%
test_housing=x_test.join(y_train)

test_housing['total_rooms']=np.log(test_housing['total_rooms']+1)
test_housing['total_bedrooms']=np.log(test_housing['total_bedrooms']+1)
test_housing['population']=np.log(test_housing['population']+1)
test_housing['households']=np.log(test_housing['households']+1)

test_housing=test_housing.join(pd.get_dummies(test_housing.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_housing['bedroom_ratio']=test_housing['total_bedrooms']/test_housing['total_rooms']
test_housing['household_rooms']=test_housing['total_rooms']/test_housing['households']

# %%
x_test,y_test=test_housing.drop(['median_house_value'],axis=1),test_housing['median_house_value']

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_train,y_train)
# Out:
# 0.9742552117681074

# %%
rf=RandomForestRegressor()
rf
# Out:
# RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()
